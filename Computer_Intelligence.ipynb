# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashfaqahmed22/ABC_Resturant/blob/main/Computer_Intelligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # Loading train dataset

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93800 entries, 0 to 93799
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     93800 non-null  int64
#  1   Name                                   93800 non-null  object
#  2   Gender                                 93800 non-null  object
#  3   Age                                    93800 non-null  float64
#  4   City                                   93800 non-null  object
#  5   Working Professional or Student        93800 non-null  object
#  6   Profession                             69168 non-null  object
#  7   Academic Pressure                      18767 non-null  float64
#  8   Work Pressure                          75022 non-null  float64
#  9   CGPA                                   18766 non-null  float64
# ...

# %%
test_ids = test_df['id']

# %% [markdown]
# # Check for missing values

# %%
print(train_df.isnull().sum())
# Out:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                36630
# Academic Pressure                        112803
# Work Pressure                             27918
# CGPA                                     112802
# Study Satisfaction                       112803
# Job Satisfaction                          27910
# Sleep Duration                                0
# Dietary Habits                                4
# Degree                                        2
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Depression                                    0
# ...

# %% [markdown]
# # Feature Engineering

# %%
X = train_df.drop(columns=['Depression'])  # Features
y = train_df['Depression']  # Target variable

# %% [markdown]
# # Apply one-hot encoding to categorical variables

# %%
X = pd.get_dummies(X, drop_first=True)
test_df = pd.get_dummies(test_df, drop_first=True)

# %% [markdown]
# # Ensure the test dataset has the same columns as the train dataset

# %%
missing_cols = set(X.columns) - set(test_df.columns)
for col in missing_cols:
    test_df[col] = 0  # Add missing columns with 0 values

# %% [markdown]
# # Reorder columns to match training data

# %%
test_df = test_df[X.columns]

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_scaled = scaler.transform(test_df)

# %% [markdown]
# # Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train the model

# %%
model = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %% [markdown]
# # Evaluate the model

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.900319829424307
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     22986
#            1       0.83      0.57      0.68      5154
#
#     accuracy                           0.90     28140
#    macro avg       0.87      0.77      0.81     28140
# weighted avg       0.90      0.90      0.89     28140

# %% [markdown]
# # Make predictions on test data

# %%
y_submission_pred = model.predict(test_scaled)

# %% [markdown]
# # Create submission file

# %%
submission = pd.DataFrame({'id': test_ids, 'Depression': y_submission_pred})
submission.to_csv('Submission2.csv', index=False)
